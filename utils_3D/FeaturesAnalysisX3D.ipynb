# %%
import os
import numpy as np
import pandas as pd
import torch

for ARCH in ["EfficientNetV2-M", "X3D-L"]:
    # Main Headline
    print("=" * 80)
    print(f"Feature Extraction - {ARCH}")
    print("=" * 80)
    for DATASET in ["SAR_RARP50"]:#, "VTS", "MultiBypass140", "SAR_RARP50"]: # JIGSAWS
        TASK = ["gestures"] if DATASET != "MultiBypass140" else ["phases", "steps"]
        for t in TASK:
            # ←– POINT THIS AT YOUR FEATURES FOLDER:
            features_dir = f"/home/gabrielg/projects/BoundedFuture++/Bounded_Future_from_GIT/data/{DATASET}/features/{ARCH}/{t}/fold 0"

            rows = []
            for fname in sorted(os.listdir(features_dir))[:]:  # just first 5 for sanity
                path = os.path.join(features_dir, fname)
                try:
                    if fname.endswith(".npy"):
                        feats = np.load(path)
                    else:
                        feats = torch.load(path, map_location="cpu").numpy()
                    rows.append({
                        'video_file': fname,
                        'feat_dim': feats.shape[0],
                        'timesteps': feats.shape[1] if feats.ndim > 1 else np.nan,
                        'mean':       feats.mean(),
                        'std':        feats.std(),
                        'min':        feats.min(),
                        'max':        feats.max(),
                    })
                except Exception as e:
                    rows.append({'video_file': fname, 'error': str(e)})

            df = pd.DataFrame(rows)
            # add header with dataset and task
            header = f"{DATASET} - {t}"
            print(f"\n\n{header}\n{'-' * len(header)}")
            # print the DataFrame in markdown format
            print(df.to_markdown(index=False))
# Out:
# ================================================================================
# Feature Extraction - EfficientNetV2-M
# ================================================================================
#
#
# SAR_RARP50 - gestures
# ---------------------
# | video_file     |   feat_dim |   timesteps |      mean |      std |       min |     max |
# |:---------------|-----------:|------------:|----------:|---------:|----------:|--------:|
# | video_01.npy   |       1280 |        5623 | 0.121739  | 0.352415 | -0.27225  | 4.78082 |
# | video_02.npy   |       1280 |        3292 | 0.136517  | 0.375275 | -0.272999 | 3.66357 |
# | video_03.npy   |       1280 |        5217 | 0.115201  | 0.306465 | -0.27411  | 3.83932 |
# | video_04.npy   |       1280 |        1301 | 0.134919  | 0.363939 | -0.269693 | 3.85508 |
# | video_05.npy   |       1280 |        2712 | 0.120554  | 0.286997 | -0.27023  | 2.89824 |
# | video_06.npy   |       1280 |        7059 | 0.0788083 | 0.319034 | -0.270787 | 5.29452 |
# | video_07.npy   |       1280 |        2715 | 0.106276  | 0.331556 | -0.270724 | 4.79108 |
# | video_08.npy   |       1280 |        1479 | 0.123943  | 0.346475 | -0.270816 | 3.13235 |
# | video_09.npy   |       1280 |        2635 | 0.126766  | 0.352752 | -0.271396 | 4.3241  |
# | video_10.npy   |       1280 |        1273 | 0.124552  | 0.373691 | -0.269952 | 4.922   |
# | video_11_1.npy |       1280 |        2368 | 0.132756  | 0.338053 | -0.273062 | 3.42127 |
# | video_11_2.npy |       1280 |        1348 | 0.114977  | 0.332451 | -0.269206 | 4.45726 |
# | video_12.npy   |       1280 |        1311 | 0.112191  | 0.358869 | -0.26969  | 6.34985 |
# | video_13.npy   |       1280 |        2720 | 0.136789  | 0.329127 | -0.270346 | 3.36619 |
# | video_14.npy   |       1280 |        2817 | 0.10273   | 0.266385 | -0.272283 | 2.64965 |
# | video_43.npy   |       1280 |        1975 | 0.134536  | 0.326992 | -0.27075  | 3.17126 |
# | video_44.npy   |       1280 |        1428 | 0.0758683 | 0.231327 | -0.270223 | 2.42895 |
# | video_45.npy   |       1280 |        1161 | 0.0871872 | 0.275372 | -0.26921  | 2.13144 |
# | video_46.npy   |       1280 |        6321 | 0.0946357 | 0.269096 | -0.27379  | 3.98081 |
# | video_47.npy   |       1280 |        3332 | 0.0990046 | 0.25277  | -0.270604 | 2.50422 |
# | video_48.npy   |       1280 |        3001 | 0.121893  | 0.293787 | -0.271653 | 2.82051 |
# | video_49.npy   |       1280 |        6863 | 0.112304  | 0.284287 | -0.272335 | 3.13779 |
# | video_50.npy   |       1280 |        2429 | 0.108268  | 0.278907 | -0.271376 | 2.32385 |
# ================================================================================
# Feature Extraction - X3D-L
# ================================================================================
#
#
# SAR_RARP50 - gestures
# ---------------------
# | video_file     |   feat_dim |   timesteps |    mean |     std |         min |      max |
# |:---------------|-----------:|------------:|--------:|--------:|------------:|---------:|
# | video_01.npy   |        192 |           4 | 1.77179 | 1.29447 | 0.0442078   |  6.66651 |
# | video_02.npy   |        192 |           2 | 1.74992 | 1.37115 | 0.043622    |  6.92312 |
# | video_03.npy   |        192 |           4 | 1.67302 | 1.27846 | 0.0379645   |  6.11834 |
# | video_04.npy   |        192 |           1 | 1.67979 | 1.35296 | 0.0650904   |  5.79199 |
# | video_05.npy   |        192 |           2 | 1.77658 | 1.31622 | 0.0394262   |  6.47071 |
# | video_06.npy   |        192 |           5 | 1.89398 | 1.36241 | 0.0496375   |  8.31993 |
# | video_07.npy   |        192 |           2 | 1.8075  | 1.35276 | 0.0324033   |  7.89735 |
# | video_08.npy   |        192 |           1 | 1.76615 | 1.40898 | 0.0200955   |  6.44015 |
# | video_09.npy   |        192 |           2 | 2.12364 | 1.58462 | 0.0336701   |  7.17011 |
# | video_10.npy   |        192 |         210 | 2.39396 | 2.04389 | 0.000671712 | 11.7291  |
# | video_11_1.npy |        192 |           2 | 1.68503 | 1.28656 | 0.00427001  |  7.33537 |
# | video_11_2.npy |        192 |           1 | 1.68263 | 1.23879 | 0.075173    |  6.63433 |
# | video_12.npy   |        192 |           1 | 1.51727 | 1.27152 | 0.0668981   |  6.80094 |
# | video_13.npy   |        192 |           2 | 1.80962 | 1.33056 | 0.0922638   |  6.44912 |
# | video_14.npy   |        192 |           2 | 2.01162 | 1.41809 | 0.060742    |  7.72697 |
# | video_15_1.npy |        192 |           2 | 1.65732 | 1.2977  | 0.0145515   |  7.16805 |
# | video_15_2.npy |        192 |           1 | 1.78431 | 1.32624 | 0.155895    |  6.74311 |
# | video_16.npy   |        192 |           3 | 1.6865  | 1.30537 | 0.0396805   |  6.35294 |
# | video_17_1.npy |        192 |         465 | 2.37572 | 2.00048 | 0           | 11.3985  |
# | video_17_2.npy |        192 |           1 | 1.52688 | 1.18482 | 0.16846     |  5.81001 |
# | video_18.npy   |        192 |           4 | 2.03706 | 1.58309 | 0.0232104   | 11.9122  |
# | video_19.npy   |        192 |           2 | 1.95727 | 1.39446 | 0.0104899   |  7.44176 |
